# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/My Drive/nvda.csv")

# %%
df
# Out:
#            Date    Open    High     Low   Close       Volume
# 0    06/01/2026  215.73  224.87  215.70  224.36  212,850,703
# 1    05/29/2026  214.58  217.86  211.13  211.14  289,410,594
# 2    05/28/2026  211.28  215.52  211.22  214.25  143,996,000
# 3    05/27/2026  214.12  214.15  208.78  212.60  167,601,203
# 4    05/26/2026  216.54  218.18  212.00  214.86  187,202,594
# ..          ...     ...     ...     ...     ...          ...
# 246  06/06/2025  142.51  143.27  141.51  141.72  153,986,203
# 247  06/05/2025  142.17  144.00  138.83  139.99  232,410,797
# 248  06/04/2025  142.19  142.39  139.55  141.92  167,120,797
# 249  06/03/2025  138.78  142.00  137.95  141.22  225,578,797
# 250  06/02/2025  135.49  138.12  135.40  137.38  197,663,109
#
# [251 rows x 6 columns]

# %%
# Date is a str, need to convert to datetime
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Date"]
# Out:
# 0     2026-06-01
# 1     2026-05-29
# 2     2026-05-28
# 3     2026-05-27
# 4     2026-05-26
#          ...
# 246   2025-06-06
# 247   2025-06-05
# 248   2025-06-04
# 249   2025-06-03
# 250   2025-06-02
# Name: Date, Length: 251, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume            object
# dtype: object

# %%
df["Volume"] = df["Volume"].str.replace(",","", regex=True)
df["Volume"] = df["Volume"].astype(np.int64)

# %%
# # If you make the date the index
# df["11-29-2025:11-30-2025"]

plt.plot(df["Date"], df["Close"])
plt.xlabel("Date")
plt.ylabel("NVDA Closing Price [$ USD]");

# %%
# Practice creating one column
df["Delta"] = df["High"] - df["Low"]

# %%
df
# Out:
#           Date    Open    High     Low   Close     Volume  Delta
# 0   2026-06-01  215.73  224.87  215.70  224.36  212850703   9.17
# 1   2026-05-29  214.58  217.86  211.13  211.14  289410594   6.73
# 2   2026-05-28  211.28  215.52  211.22  214.25  143996000   4.30
# 3   2026-05-27  214.12  214.15  208.78  212.60  167601203   5.37
# 4   2026-05-26  216.54  218.18  212.00  214.86  187202594   6.18
# ..         ...     ...     ...     ...     ...        ...    ...
# 246 2025-06-06  142.51  143.27  141.51  141.72  153986203   1.76
# 247 2025-06-05  142.17  144.00  138.83  139.99  232410797   5.17
# 248 2025-06-04  142.19  142.39  139.55  141.92  167120797   2.84
# 249 2025-06-03  138.78  142.00  137.95  141.22  225578797   4.05
# 250 2025-06-02  135.49  138.12  135.40  137.38  197663109   2.72
#
# [251 rows x 7 columns]

# %%
# Practice deleting column
df.drop("Delta", axis=1)
# Out:
#           Date    Open    High     Low   Close     Volume
# 0   2026-06-01  215.73  224.87  215.70  224.36  212850703
# 1   2026-05-29  214.58  217.86  211.13  211.14  289410594
# 2   2026-05-28  211.28  215.52  211.22  214.25  143996000
# 3   2026-05-27  214.12  214.15  208.78  212.60  167601203
# 4   2026-05-26  216.54  218.18  212.00  214.86  187202594
# ..         ...     ...     ...     ...     ...        ...
# 246 2025-06-06  142.51  143.27  141.51  141.72  153986203
# 247 2025-06-05  142.17  144.00  138.83  139.99  232410797
# 248 2025-06-04  142.19  142.39  139.55  141.92  167120797
# 249 2025-06-03  138.78  142.00  137.95  141.22  225578797
# 250 2025-06-02  135.49  138.12  135.40  137.38  197663109
#
# [251 rows x 6 columns]
